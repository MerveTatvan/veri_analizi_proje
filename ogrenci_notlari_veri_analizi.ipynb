# %% [markdown]
# # 🎓 Öğrenci Notları Veri Analizi
#
# Bu çalışmada bir öğrenci veri seti kullanılarak bölümlere göre not analizi,
# yaş–not ilişkisi ve not dağılımı incelenmiştir.
# Amaç, pandas ve matplotlib kullanarak temel veri analizi ve görselleştirme becerilerini göstermektir.

# %% [markdown]
# ## 📂 Veri Setinin Yüklenmesi
#
# Bu bölümde analizde kullanılacak öğrenci veri seti yüklenmiş ve incelenmiştir.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/ogrenciler.csv")
df
# Out:
#     isim  yas       bolum  not
# 0  Merve   21  Bilgisayar   85
# 1  Ahmet   25      Makine   90
# 2   Ayşe   23    Endüstri   78
# 3    Can   30  Bilgisayar   88

# %% [markdown]
# ## 📊 Bölümlere Göre Ortalama Not Analizi

# %%
bolum_ort = df.groupby("bolum")["not"].mean()

bolum_ort.plot(kind="bar")
plt.title("Bölümlere Göre Ortalama Not")
plt.xlabel("Bölüm")
plt.ylabel("Ortalama Not")
plt.show()

# %% [markdown]
# ### 📊 Bölümlere Göre Ortalama Not Analizi
#
# Grafikte, Makine bölümünün ortalama notunun diğer bölümlere göre daha yüksek olduğu görülmektedir.
# Bilgisayar bölümü orta seviyede yer alırken, Endüstri bölümünün ortalaması daha düşüktür.
# Ancak veri setindeki öğrenci sayısı sınırlı olduğu için bu sonuçlar ön değerlendirme niteliğindedir.

# %% [markdown]
# ## 📈 Yaş – Not İlişkisi Analizi

# %%
plt.scatter(df["yas"], df["not"])
plt.title("Yaş - Not İlişkisi")
plt.xlabel("Yaş")
plt.ylabel("Not")
plt.show()

# %% [markdown]
# ### 📈 Yaş – Not İlişkisi Analizi
#
# Scatter plot incelendiğinde öğrencilerin yaşları ile notları arasında belirgin bir doğrusal ilişki bulunmamaktadır.
# Farklı yaş gruplarında benzer not seviyeleri gözlemlenmiştir.
# Bu durum, akademik başarının yaş dışında başka faktörlere bağlı olabileceğini göstermektedir.

# %% [markdown]
# ## 📉 Not Dağılımı Analizi

# %%
plt.hist(df["not"], bins=5)
plt.title("Not Dağılımı")
plt.xlabel("Not")
plt.ylabel("Öğrenci Sayısı")
plt.show()

# %% [markdown]
# ### 📉 Not Dağılımı Analizi
#
# Histogram incelendiğinde öğrencilerin notlarının büyük ölçüde 80–90 aralığında toplandığı görülmektedir.
# Bu durum, genel başarı seviyesinin orta–yüksek düzeyde olduğunu göstermektedir.
# Daha düşük notların sınırlı sayıda olması, veri setinde başarısız öğrenci oranının düşük olduğunu düşündürmektedir.
# Ancak veri setindeki öğrenci sayısının az olması nedeniyle bu sonuçlar genelleştirilmemelidir.

# %% [markdown]
# ## 🏁 Sonuç
#
# Bu çalışma kapsamında pandas ve matplotlib kullanılarak temel veri analizi adımları uygulanmıştır.
# Bölümlere göre not ortalamaları incelenmiş, yaş ile not arasında belirgin bir ilişki olmadığı gözlemlenmiştir.
# Ayrıca notların genel olarak orta–yüksek aralıkta dağıldığı görülmüştür.
# Bu proje, veri analizi sürecinin uçtan uca uygulanmasını göstermektedir.
