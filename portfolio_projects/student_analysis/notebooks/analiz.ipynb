# %%
import pandas as pd

df = pd.read_csv("data/ogrenciler.csv")
df
# Out:
#     isim  yas       bolum  not
# 0  Merve   21  Bilgisayar   85
# 1  Ahmet   25      Makine   90
# 2   Ayşe   23    Endüstri   78
# 3    Can   30  Bilgisayar   88

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   isim    4 non-null      object
#  1   yas     4 non-null      int64
#  2   bolum   4 non-null      object
#  3   not     4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 260.0+ bytes
#             yas        not
# count   4.00000   4.000000
# mean   24.75000  85.250000
# std     3.86221   5.251984
# min    21.00000  78.000000
# 25%    22.50000  83.250000
# 50%    24.00000  86.500000
# 75%    26.25000  88.500000
# max    30.00000  90.000000

# %%
import matplotlib.pyplot as plt

bolum_ort = df.groupby("bolum")["not"].mean()
bolum_ort.plot(kind="bar")
plt.show()
